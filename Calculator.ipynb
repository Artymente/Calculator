# %%
#calculator
import math
from IPython.display import clear_output
print("\n#####\033[1m\033[1mCalculator\033[0m#####\n")

print("What language do you prefer to continue?\n Qual idioma você prefere continuar?\n")

#idiomas disponiveis
print("[1] Português")
print("[2] Inglês")

i = int(input())
#se for portugues segue o menu
if i == 1:
  clear_output()
  while True:
    print("\nQual operação deseja realizar?\n")
    print("[1] Adição")
    print("[2] Subtração")
    print("[3] Multiplicação")
    print("[4] Divisão")
    print("[5] Resto da Divisao")
    print("[6] potenciação")
    print("[7] raiz quadrada")
    print("[8] raiz cubica")
    print("[9] regra de 3 simples")
    print("[10] Lei de Ohm(calcular a amperagem)")
    print("[11] Formulas fisicas.")

    r = int(input("Digite um número:"))

    #Adçao

    if r == 1:
     clear_output()
     print("\nAdição\n")
     num1 = int(input("Digite um número:\n"))
     num2 =int(input("Digite mais um número:\n"))
     soma = num1 + num2
     print("O resultado é: ",soma)

    #subtraçao

    elif r == 2:
     clear_output()
     print("\nSubtraçao\n")
     num1 = int(input("Digite um número:\n"))
     num2 =int(input("Digite mais um número:\n"))
     soma = num1 - num2
     print("O resultado é: ",soma)

    #multiplicacao

    elif r == 3:
     clear_output()
     print("\nMultiplicação\n")
     num1 = int(input("Digite um número:\n"))
     num2 =int(input("Digite mais um número:\n"))
     soma = num1 * num2
     print("O resultado é: ",soma)

    #divisao

    elif r == 4:
     clear_output()
     print("\nDivisão\n")
     num1 = int(input("Digite um número:\n"))
     num2 =int(input("Digite mais um número:\n"))
     soma = num1 / num2
     print("O resultado é: ",soma)

   #resto da divisao
    elif r == 5:
     clear_output()
     print("\nResto da Divisao\n")
     num1 = int(input("Digite um número:\n"))
     num2 =int(input("Digite mais um número:\n"))
     soma = num1 % num2
     print("O resultado é: ",soma)

    #potencia

    elif r == 6:
     clear_output()
     print("\npotenciação\n")
     num1 = int(input("Digite um número:\n"))
     num2 =int(input("Digite o número :\n"))
     soma = math.pow(num1 , num2)
     print("O resultado é: ",soma)

    elif r == 7:
     clear_output()
     print("\nRaiz Quadrada\n")
     num1 = int(input("Digite um número:\n"))
     soma = math.sqrt(num1)
     print("A raiz quadrada é: ",soma)

    elif r == 8:
     clear_output()
     print("\nRaiz cubica\n")
     num1 = int(input("Digite um número:\n"))
     soma = num1**(1/3)
     print("A raiz quadrada é: ",soma)

    elif r == 9:
     clear_output()
     print("\nRegra de 3 Simples\n")
     num1 = int(input("Digite o primeiro numero:\n"))
     num2 =int(input("está para qual numero :\n"))
     num3 =int(input("Como o Numero: \n""esta para X"))
     soma = (num1 * num2)/num3
     print("X é igual á : ",soma)

    elif r == 10:
     clear_output()
     print("\nLei de Ohm\n")
     num1 = int(input("Qual a Potecia da rede(watts):\n"))
     num2 =int(input("Qual a corrente(volts) :\n"))
     soma = (num1 / num2)*1.20
     print("A Amperagem ideal é : ",soma)

    elif r == 11:
      clear_output()
      print("\nFormulas fisicas\n")
      print("[1] Velocidade")
      print("[2] Tempo")
      print("[3] Distancia")

      r = int(input("Digite um número:"))
      if r == 1:
       clear_output()
       print("\nVelocidade\n")
       distancia = int(input("Qual a Distancia percorrida em metros"))
       tempo = int(input("Qual o tempo percorrida em segundos"))
       velocidade = distancia / tempo
       print("A velocidade é: ",velocidade)

      elif r == 2:
       clear_output()
       print("\nTempo\n")
       distancia = int(input("Qual a Distancia percorrida em metros"))
       velocidade = int(input("Qual a velocidade percorrida em  metros por segundos"))
       tempo = distancia / velocidade
       print("o tempo é: ",velocidade)
      elif r == 3:
       clear_output()
       print("\nTempo\n")
       tempo = int(input("Qual o tempo em segundos"))
       velocidade = int(input("Qual a velocidade percorrida em  metros por segundos"))
       distancia = tempo * velocidade
       print("o tempo é: ",distancia)
      else:
        print("Invalid option")
    if input("Deseja realizar outra operação? (s/n): ") != "s":
                break # sai do loop do menu em português
    else:
      print("Invalid option")



elif i ==2:
  clear_output()
  while True:
    print("\nWhat operation do you want to perform?\n")
    print("[1] Addition")
    print("[2] Subtraction")
    print("[3] Multiplication")
    print("[4] Division")
    print("[5] Remainder of Division")
    print("[6] Exponentation")
    print("[7] Square root")
    print("[8] Cubic root")
    print("[9] Simple 3-Rule")
    print("[10] Ohm's Law")
    print("[11] Physical Formulas")

    r = int(input("Enter a number:"))

    if r ==1:
     clear_output()
     print("\nAddition\n")
     num1 = int(input("Enter a number:\n"))
     num2 =int(input("Enter another number:\n"))
     soma = num1 + num2
     print("The result is: ",soma)
    elif r == 2:
     clear_output()
     print("\nSubtraction\n")
     num1 = int(input("Enter a number:\n"))
     num2 =int(input("Enter another number:\n"))
     soma = num1 - num2
     print("The result is: ",soma)
    elif r == 3:
     clear_output()
     print("\nMultiplication\n")
     num1 = int(input("Enter a number:\n"))
     num2 =int(input("Enter another number:\n"))
     soma = num1 * num2
     print("The result is: ",soma)
    elif r == 4:
      clear_output()
      print("\nDivision\n")
      num1 = int(input("Enter a number:\n"))
      num2 =int(input("Enter another number:\n"))
      soma = num1 / num2
      print("The result is: ",soma)
    elif r == 5:
      clear_output()
      print("\nRemainder of Division\n")
      num1 = int(input("Enter a number:\n"))
      num2 =int(input("Enter another number:\n"))
      soma = num1 % num2
      print("The result is: ",soma)
    elif r == 6:
      clear_output()
      print("\nExponentiation\n")
      num1 = int(input("Enter a number:\n"))
      num2 =int(input("Enter the number :\n"))
      soma = math.pow(num1 , num2)
      print("The result is: ",soma)
    elif r == 7:
      clear_output()
      print("\nSquare root\n")
      num1 = int(input("Enter a number:\n"))
      soma = math.sqrt(num1)
      print("The square root is: ",soma)
      back
    elif r == 8:
      clear_output()
      print("\nCubic root\n")
      num1 = int(input("Enter a number:\n"))
      soma = num1**(1/3)
      print("The cubic root is: ",soma)

    elif r == 9:
     clear_output()
     print("\nSimple Rule of 3\n")
     num1 = int(input("Enter the first number:\n"))
     num2 =int(input("what number is it for:\n"))
     num3 =int(input("Like the Number: \n""this is for X"))
     sum = (num1 * num2)/num3
     print("X is equal to: ",sum)
    elif r == 10:
     clear_output()
     print("\nOhm's Law\n")
     num1 = int(input("What is the power of the network (watts):\n"))
     num2 =int(input("What is the current(volts) :\n"))
     sum = (num1 / num2)*1.20
     print("The ideal Amperage is: ",sum)

    elif r == 11:
      clear_output()
      print("\nPhysical formulas\n")
      print("[1] Speed")
      print("[2] Time")
      print("[3] Distance")

      r = int(input("Enter a number:"))
      if r == 1:
       clear_output()
       print("\nSpeed\n")
       distance = int(input("What is the distance traveled in meters"))
       time = int(input("How long in seconds"))
       speed = distance / time
       print("The speed is: ",speed)

      elif r == 2:
       clear_output()
       print("\nTime\n")
       distance = int(input("What is the distance traveled in meters"))
       speed = int(input("What is the speed traveled in meters per second"))
       time = distance / speed
       print("time is: ",speed)
      elif r == 3:
       clear_output()
       print("\nTime\n")
       time = int(input("What is the time in seconds"))
       speed = int(input("What is the speed traveled in meters per second"))
       distance = time * speed
       print("time is: ",distance)
      else:
        print("Invalid option")
    if input("Do you want to continue? (y/n): ") != "y":
                break # sai do loop do menu em portu
    else:
      print("Invalid option")


else:
    print("Invalid option")
